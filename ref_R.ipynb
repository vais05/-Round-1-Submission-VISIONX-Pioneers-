# %%
# !pip install tensorflow opencv-python
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.17.1)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (4.10.0.84)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.12.1)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.25.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.68.0)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.17.1)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.5.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.13.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow) (0.1.2)

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np
import cv2
import os
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')

# Define paths for Ref and Non-Ref images
base_dir = '/content/drive/My Drive/dataset_Ref_Non_Ref'
reflection_dir = os.path.join(base_dir, 'Ref')  # Ref images
clear_dir = os.path.join(base_dir, 'Non_Ref')  # Non-Ref images

def load_images_from_folder(folder, target_size=(256, 256)):
    images = []
    for filename in sorted(os.listdir(folder)):
        img_path = os.path.join(folder, filename)
        img = cv2.imread(img_path)
        if img is not None:
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            img = cv2.resize(img, target_size)
            img = img / 255.0
            images.append(img)
    return np.array(images)


X_train = load_images_from_folder(reflection_dir)  # Ref images
Y_train = load_images_from_folder(clear_dir)  # Non-Ref images

print(f"Loaded {len(X_train)} images with reflections.")
print(f"Loaded {len(Y_train)} clear images.")

assert len(X_train) == len(Y_train), "Mismatch between input and output datasets."

def unet_model(input_shape=(256, 256, 3)):
    inputs = layers.Input(input_shape)

    # Encoder
    c1 = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(inputs)
    c1 = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(c1)
    p1 = layers.MaxPooling2D((2, 2))(c1)

    c2 = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(p1)
    c2 = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(c2)
    p2 = layers.MaxPooling2D((2, 2))(c2)

    c3 = layers.Conv2D(256, (3, 3), activation='relu', padding='same')(p2)
    c3 = layers.Conv2D(256, (3, 3), activation='relu', padding='same')(c3)
    p3 = layers.MaxPooling2D((2, 2))(c3)

    # Bottleneck
    c4 = layers.Conv2D(512, (3, 3), activation='relu', padding='same')(p3)
    c4 = layers.Conv2D(512, (3, 3), activation='relu', padding='same')(c4)

    # Decoder
    u5 = layers.Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(c4)
    u5 = layers.concatenate([u5, c3])
    c5 = layers.Conv2D(256, (3, 3), activation='relu', padding='same')(u5)
    c5 = layers.Conv2D(256, (3, 3), activation='relu', padding='same')(c5)

    u6 = layers.Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(c5)
    u6 = layers.concatenate([u6, c2])
    c6 = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(u6)
    c6 = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(c6)

    u7 = layers.Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(c6)
    u7 = layers.concatenate([u7, c1])
    c7 = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(u7)
    c7 = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(c7)

    outputs = layers.Conv2D(3, (1, 1), activation='sigmoid')(c7)

    model = models.Model(inputs, outputs)
    return model

# Compile  model
model = unet_model()
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['accuracy'])
model.summary()

batch_size = 16
num_epochs = 50
steps_per_epoch = len(X_train) // batch_size

def data_generator(X, Y, batch_size):
    while True:
        for i in range(0, len(X), batch_size):
            X_batch = X[i:i+batch_size]
            Y_batch = Y[i:i+batch_size]
            yield (np.array(X_batch), np.array(Y_batch))

train_gen = data_generator(X_train, Y_train, batch_size)

history = model.fit(train_gen, epochs=num_epochs, steps_per_epoch=steps_per_epoch)

model.save('reflection_removal_unet.h5')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Loaded 30 images with reflections.
# Loaded 30 clear images.
# Model: "functional_8"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_8             │ (None, 256, 256, 3)    │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_120 (Conv2D)       │ (None, 256, 256, 64)   │          1,792 │ input_layer_8[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_121 (Conv2D)       │ (None, 256, 256, 64)   │         36,928 │ conv2d_120[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_24          │ (None, 128, 128, 64)   │              0 │ conv2d_121[0][0]       │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_122 (Conv2D)       │ (None, 128, 128, 128)  │         73,856 │ max_pooling2d_24[0][0] │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_123 (Conv2D)       │ (None, 128, 128, 128)  │        147,584 │ conv2d_122[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_25          │ (None, 64, 64, 128)    │              0 │ conv2d_123[0][0]       │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_124 (Conv2D)       │ (None, 64, 64, 256)    │        295,168 │ max_pooling2d_25[0][0] │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_125 (Conv2D)       │ (None, 64, 64, 256)    │        590,080 │ conv2d_124[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_26          │ (None, 32, 32, 256)    │              0 │ conv2d_125[0][0]       │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_126 (Conv2D)       │ (None, 32, 32, 512)    │      1,180,160 │ max_pooling2d_26[0][0] │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_127 (Conv2D)       │ (None, 32, 32, 512)    │      2,359,808 │ conv2d_126[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_24       │ (None, 64, 64, 256)    │        524,544 │ conv2d_127[0][0]       │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_24            │ (None, 64, 64, 512)    │              0 │ conv2d_transpose_24[0… │
# │ (Concatenate)             │                        │                │ conv2d_125[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_128 (Conv2D)       │ (None, 64, 64, 256)    │      1,179,904 │ concatenate_24[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_129 (Conv2D)       │ (None, 64, 64, 256)    │        590,080 │ conv2d_128[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_25       │ (None, 128, 128, 128)  │        131,200 │ conv2d_129[0][0]       │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_25            │ (None, 128, 128, 256)  │              0 │ conv2d_transpose_25[0… │
# │ (Concatenate)             │                        │                │ conv2d_123[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_130 (Conv2D)       │ (None, 128, 128, 128)  │        295,040 │ concatenate_25[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_131 (Conv2D)       │ (None, 128, 128, 128)  │        147,584 │ conv2d_130[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_26       │ (None, 256, 256, 64)   │         32,832 │ conv2d_131[0][0]       │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_26            │ (None, 256, 256, 128)  │              0 │ conv2d_transpose_26[0… │
# │ (Concatenate)             │                        │                │ conv2d_121[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_132 (Conv2D)       │ (None, 256, 256, 64)   │         73,792 │ concatenate_26[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_133 (Conv2D)       │ (None, 256, 256, 64)   │         36,928 │ conv2d_132[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_134 (Conv2D)       │ (None, 256, 256, 3)    │            195 │ conv2d_133[0][0]       │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 7,697,475 (29.36 MB)
#  Trainable params: 7,697,475 (29.36 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - accuracy: 0.8193 - loss: 0.0680
# Epoch 2/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - accuracy: 0.8025 - loss: 0.0322
# Epoch 3/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 612ms/step - accuracy: 0.8194 - loss: 0.0748
# Epoch 4/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 553ms/step - accuracy: 0.8025 - loss: 0.0316
# Epoch 5/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 612ms/step - accuracy: 0.8194 - loss: 0.0650
# Epoch 6/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 551ms/step - accuracy: 0.8025 - loss: 0.0332
# Epoch 7/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 601ms/step - accuracy: 0.8194 - loss: 0.0648
# Epoch 8/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 561ms/step - accuracy: 0.8025 - loss: 0.0338
# Epoch 9/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 602ms/step - accuracy: 0.8194 - loss: 0.0648
# Epoch 10/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 557ms/step - accuracy: 0.8025 - loss: 0.0331
# Epoch 11/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 612ms/step - accuracy: 0.8194 - loss: 0.0647
# Epoch 12/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 564ms/step - accuracy: 0.8025 - loss: 0.0322
# Epoch 13/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 629ms/step - accuracy: 0.8194 - loss: 0.0652
# Epoch 14/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 563ms/step - accuracy: 0.8025 - loss: 0.0317
# Epoch 15/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 601ms/step - accuracy: 0.8194 - loss: 0.0658
# Epoch 16/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 563ms/step - accuracy: 0.8025 - loss: 0.0316
# Epoch 17/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 610ms/step - accuracy: 0.8194 - loss: 0.0654
# Epoch 18/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 558ms/step - accuracy: 0.8025 - loss: 0.0318
# Epoch 19/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 611ms/step - accuracy: 0.8194 - loss: 0.0649
# Epoch 20/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 554ms/step - accuracy: 0.8025 - loss: 0.0321
# Epoch 21/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 616ms/step - accuracy: 0.8194 - loss: 0.0648
# Epoch 22/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 557ms/step - accuracy: 0.8025 - loss: 0.0321
# Epoch 23/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 608ms/step - accuracy: 0.8194 - loss: 0.0648
# Epoch 24/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 557ms/step - accuracy: 0.8025 - loss: 0.0319
# Epoch 25/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 609ms/step - accuracy: 0.8194 - loss: 0.0649
# Epoch 26/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 560ms/step - accuracy: 0.8025 - loss: 0.0317
# Epoch 27/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 606ms/step - accuracy: 0.8194 - loss: 0.0650
# Epoch 28/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 559ms/step - accuracy: 0.8025 - loss: 0.0316
# Epoch 29/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 609ms/step - accuracy: 0.8194 - loss: 0.0650
# Epoch 30/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 557ms/step - accuracy: 0.8025 - loss: 0.0316
# Epoch 31/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 612ms/step - accuracy: 0.8194 - loss: 0.0648
# Epoch 32/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 562ms/step - accuracy: 0.8025 - loss: 0.0316
# Epoch 33/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 619ms/step - accuracy: 0.8194 - loss: 0.0648
# Epoch 34/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 556ms/step - accuracy: 0.8025 - loss: 0.0316
# Epoch 35/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 611ms/step - accuracy: 0.8194 - loss: 0.0647
# Epoch 36/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 564ms/step - accuracy: 0.8025 - loss: 0.0315
# Epoch 37/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 616ms/step - accuracy: 0.8194 - loss: 0.0648
# Epoch 38/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 569ms/step - accuracy: 0.8025 - loss: 0.0313
# Epoch 39/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 614ms/step - accuracy: 0.8194 - loss: 0.0649
# Epoch 40/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 570ms/step - accuracy: 0.8025 - loss: 0.0312
# Epoch 41/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 621ms/step - accuracy: 0.8194 - loss: 0.0647
# Epoch 42/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 575ms/step - accuracy: 0.8025 - loss: 0.0312
# Epoch 43/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 663ms/step - accuracy: 0.8194 - loss: 0.0646
# Epoch 44/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 562ms/step - accuracy: 0.8025 - loss: 0.0311
# Epoch 45/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 619ms/step - accuracy: 0.8194 - loss: 0.0646
# Epoch 46/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 564ms/step - accuracy: 0.8025 - loss: 0.0308
# Epoch 47/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 618ms/step - accuracy: 0.8194 - loss: 0.0647
# Epoch 48/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 564ms/step - accuracy: 0.8025 - loss: 0.0305
# Epoch 49/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 625ms/step - accuracy: 0.8194 - loss: 0.0647
# Epoch 50/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 571ms/step - accuracy: 0.8025 - loss: 0.0302
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
import numpy as np
import cv2
import os
import math
from google.colab import drive

# Mount Google
drive.mount('/content/drive')

base_dir = '/content/drive/My Drive/dataset_Ref_Non_Ref'
reflection_dir = os.path.join(base_dir, 'Ref')  # Ref images
clear_dir = os.path.join(base_dir, 'Non_Ref')  # Non-Ref images

def load_images_from_folder(folder, target_size=(256, 256)):
    images = []
    for filename in sorted(os.listdir(folder)):
        img_path = os.path.join(folder, filename)
        img = cv2.imread(img_path)
        if img is not None:
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            img = cv2.resize(img, target_size)
            img = img / 255.0
            images.append(img)
    return np.array(images)



X_train = load_images_from_folder(reflection_dir)  # Ref images
Y_train = load_images_from_folder(clear_dir)  # Non-Ref images

print(f"Loaded {len(X_train)} images with reflections.")
print(f"Loaded {len(Y_train)} clear images.")

assert len(X_train) == len(Y_train), "Mismatch between input and output datasets."

def unet_model(input_shape=(256, 256, 3)):
    inputs = layers.Input(input_shape)

    # Encoder
    c1 = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(inputs)
    c1 = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(c1)
    p1 = layers.MaxPooling2D((2, 2))(c1)

    c2 = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(p1)
    c2 = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(c2)
    p2 = layers.MaxPooling2D((2, 2))(c2)

    c3 = layers.Conv2D(256, (3, 3), activation='relu', padding='same')(p2)
    c3 = layers.Conv2D(256, (3, 3), activation='relu', padding='same')(c3)
    p3 = layers.MaxPooling2D((2, 2))(c3)

    # Bottleneck
    c4 = layers.Conv2D(512, (3, 3), activation='relu', padding='same')(p3)
    c4 = layers.Conv2D(512, (3, 3), activation='relu', padding='same')(c4)

    # Decoder
    u5 = layers.Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(c4)
    u5 = layers.concatenate([u5, c3])
    c5 = layers.Conv2D(256, (3, 3), activation='relu', padding='same')(u5)
    c5 = layers.Conv2D(256, (3, 3), activation='relu', padding='same')(c5)

    u6 = layers.Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(c5)
    u6 = layers.concatenate([u6, c2])
    c6 = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(u6)
    c6 = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(c6)

    u7 = layers.Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(c6)
    u7 = layers.concatenate([u7, c1])
    c7 = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(u7)
    c7 = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(c7)

    outputs = layers.Conv2D(3, (1, 1), activation='sigmoid')(c7)

    model = models.Model(inputs, outputs)
    return model

model = unet_model()
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['accuracy'])
model.summary()

split_idx = int(0.8 * len(X_train))
X_train, X_val = X_train[:split_idx], X_train[split_idx:]
Y_train, Y_val = Y_train[:split_idx], Y_train[split_idx:]

batch_size = 16
num_epochs = 50

# Calculate steps
steps_per_epoch = math.ceil(len(X_train) / batch_size)
validation_steps = math.ceil(len(X_val) / batch_size)

# Custom data generator
def data_generator(X, Y, batch_size):
    while True:
        indices = np.random.permutation(len(X))
        for i in range(0, len(X), batch_size):
            batch_indices = indices[i:i + batch_size]
            X_batch = [X[j] for j in batch_indices]
            Y_batch = [Y[j] for j in batch_indices]
            yield np.array(X_batch), np.array(Y_batch)

train_gen = data_generator(X_train, Y_train, batch_size)
val_gen = data_generator(X_val, Y_val, batch_size)

# Train the model
history = model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=num_epochs,
    steps_per_epoch=steps_per_epoch,
    validation_steps=validation_steps
)
model.save('reflection_removal_unet.h5')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Loaded 30 images with reflections.
# Loaded 30 clear images.
# Model: "functional_9"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_9             │ (None, 256, 256, 3)    │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_135 (Conv2D)       │ (None, 256, 256, 64)   │          1,792 │ input_layer_9[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_136 (Conv2D)       │ (None, 256, 256, 64)   │         36,928 │ conv2d_135[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_27          │ (None, 128, 128, 64)   │              0 │ conv2d_136[0][0]       │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_137 (Conv2D)       │ (None, 128, 128, 128)  │         73,856 │ max_pooling2d_27[0][0] │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_138 (Conv2D)       │ (None, 128, 128, 128)  │        147,584 │ conv2d_137[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_28          │ (None, 64, 64, 128)    │              0 │ conv2d_138[0][0]       │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_139 (Conv2D)       │ (None, 64, 64, 256)    │        295,168 │ max_pooling2d_28[0][0] │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_140 (Conv2D)       │ (None, 64, 64, 256)    │        590,080 │ conv2d_139[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_29          │ (None, 32, 32, 256)    │              0 │ conv2d_140[0][0]       │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_141 (Conv2D)       │ (None, 32, 32, 512)    │      1,180,160 │ max_pooling2d_29[0][0] │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_142 (Conv2D)       │ (None, 32, 32, 512)    │      2,359,808 │ conv2d_141[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_27       │ (None, 64, 64, 256)    │        524,544 │ conv2d_142[0][0]       │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_27            │ (None, 64, 64, 512)    │              0 │ conv2d_transpose_27[0… │
# │ (Concatenate)             │                        │                │ conv2d_140[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_143 (Conv2D)       │ (None, 64, 64, 256)    │      1,179,904 │ concatenate_27[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_144 (Conv2D)       │ (None, 64, 64, 256)    │        590,080 │ conv2d_143[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_28       │ (None, 128, 128, 128)  │        131,200 │ conv2d_144[0][0]       │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_28            │ (None, 128, 128, 256)  │              0 │ conv2d_transpose_28[0… │
# │ (Concatenate)             │                        │                │ conv2d_138[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_145 (Conv2D)       │ (None, 128, 128, 128)  │        295,040 │ concatenate_28[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_146 (Conv2D)       │ (None, 128, 128, 128)  │        147,584 │ conv2d_145[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_29       │ (None, 256, 256, 64)   │         32,832 │ conv2d_146[0][0]       │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_29            │ (None, 256, 256, 128)  │              0 │ conv2d_transpose_29[0… │
# │ (Concatenate)             │                        │                │ conv2d_136[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_147 (Conv2D)       │ (None, 256, 256, 64)   │         73,792 │ concatenate_29[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_148 (Conv2D)       │ (None, 256, 256, 64)   │         36,928 │ conv2d_147[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_149 (Conv2D)       │ (None, 256, 256, 3)    │            195 │ conv2d_148[0][0]       │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 7,697,475 (29.36 MB)
#  Trainable params: 7,697,475 (29.36 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 4s/step - accuracy: 0.8145 - loss: 0.0576 - val_accuracy: 0.7983 - val_loss: 0.0309
# Epoch 2/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 452ms/step - accuracy: 0.8145 - loss: 0.0567 - val_accuracy: 0.7983 - val_loss: 0.0314
# Epoch 3/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 465ms/step - accuracy: 0.8154 - loss: 0.0551 - val_accuracy: 0.7983 - val_loss: 0.0320
# Epoch 4/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 434ms/step - accuracy: 0.8149 - loss: 0.0530 - val_accuracy: 0.7983 - val_loss: 0.0317
# Epoch 5/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 431ms/step - accuracy: 0.8142 - loss: 0.0543 - val_accuracy: 0.7983 - val_loss: 0.0313
# Epoch 6/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 430ms/step - accuracy: 0.8141 - loss: 0.0529 - val_accuracy: 0.7983 - val_loss: 0.0306
# Epoch 7/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 442ms/step - accuracy: 0.8149 - loss: 0.0545 - val_accuracy: 0.7983 - val_loss: 0.0301
# Epoch 8/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 439ms/step - accuracy: 0.8137 - loss: 0.0525 - val_accuracy: 0.7983 - val_loss: 0.0300
# Epoch 9/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 441ms/step - accuracy: 0.8149 - loss: 0.0516 - val_accuracy: 0.7983 - val_loss: 0.0304
# Epoch 10/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 432ms/step - accuracy: 0.8149 - loss: 0.0560 - val_accuracy: 0.7983 - val_loss: 0.0309
# Epoch 11/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 437ms/step - accuracy: 0.8145 - loss: 0.0543 - val_accuracy: 0.7983 - val_loss: 0.0307
# Epoch 12/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 442ms/step - accuracy: 0.8149 - loss: 0.0557 - val_accuracy: 0.7983 - val_loss: 0.0302
# Epoch 13/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 444ms/step - accuracy: 0.8137 - loss: 0.0537 - val_accuracy: 0.7983 - val_loss: 0.0301
# Epoch 14/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 448ms/step - accuracy: 0.8150 - loss: 0.0559 - val_accuracy: 0.7983 - val_loss: 0.0306
# Epoch 15/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 458ms/step - accuracy: 0.8149 - loss: 0.0561 - val_accuracy: 0.7983 - val_loss: 0.0310
# Epoch 16/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 459ms/step - accuracy: 0.8154 - loss: 0.0544 - val_accuracy: 0.7983 - val_loss: 0.0311
# Epoch 17/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 449ms/step - accuracy: 0.8145 - loss: 0.0524 - val_accuracy: 0.7983 - val_loss: 0.0307
# Epoch 18/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 455ms/step - accuracy: 0.8149 - loss: 0.0540 - val_accuracy: 0.7983 - val_loss: 0.0299
# Epoch 19/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 451ms/step - accuracy: 0.8146 - loss: 0.0540 - val_accuracy: 0.7983 - val_loss: 0.0296
# Epoch 20/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 454ms/step - accuracy: 0.8163 - loss: 0.0549 - val_accuracy: 0.7983 - val_loss: 0.0297
# Epoch 21/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 448ms/step - accuracy: 0.8145 - loss: 0.0499 - val_accuracy: 0.7983 - val_loss: 0.0297
# Epoch 22/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 452ms/step - accuracy: 0.8158 - loss: 0.0543 - val_accuracy: 0.7983 - val_loss: 0.0302
# Epoch 23/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 448ms/step - accuracy: 0.8149 - loss: 0.0531 - val_accuracy: 0.7983 - val_loss: 0.0300
# Epoch 24/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 450ms/step - accuracy: 0.8149 - loss: 0.0521 - val_accuracy: 0.7983 - val_loss: 0.0296
# Epoch 25/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 441ms/step - accuracy: 0.8158 - loss: 0.0548 - val_accuracy: 0.7983 - val_loss: 0.0291
# Epoch 26/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 448ms/step - accuracy: 0.8149 - loss: 0.0555 - val_accuracy: 0.7983 - val_loss: 0.0288
# Epoch 27/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 454ms/step - accuracy: 0.8149 - loss: 0.0541 - val_accuracy: 0.7983 - val_loss: 0.0292
# Epoch 28/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 449ms/step - accuracy: 0.8149 - loss: 0.0514 - val_accuracy: 0.7983 - val_loss: 0.0299
# Epoch 29/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 458ms/step - accuracy: 0.8155 - loss: 0.0554 - val_accuracy: 0.7983 - val_loss: 0.0304
# Epoch 30/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 444ms/step - accuracy: 0.8149 - loss: 0.0524 - val_accuracy: 0.7983 - val_loss: 0.0304
# Epoch 31/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 449ms/step - accuracy: 0.8145 - loss: 0.0539 - val_accuracy: 0.7983 - val_loss: 0.0299
# Epoch 32/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 448ms/step - accuracy: 0.8158 - loss: 0.0542 - val_accuracy: 0.7983 - val_loss: 0.0294
# Epoch 33/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 432ms/step - accuracy: 0.8142 - loss: 0.0521 - val_accuracy: 0.7983 - val_loss: 0.0291
# Epoch 34/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 431ms/step - accuracy: 0.8150 - loss: 0.0524 - val_accuracy: 0.7983 - val_loss: 0.0294
# Epoch 35/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 443ms/step - accuracy: 0.8149 - loss: 0.0554 - val_accuracy: 0.7983 - val_loss: 0.0296
# Epoch 36/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 430ms/step - accuracy: 0.8142 - loss: 0.0549 - val_accuracy: 0.7983 - val_loss: 0.0294
# Epoch 37/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 434ms/step - accuracy: 0.8149 - loss: 0.0551 - val_accuracy: 0.7983 - val_loss: 0.0291
# Epoch 38/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 433ms/step - accuracy: 0.8149 - loss: 0.0552 - val_accuracy: 0.7983 - val_loss: 0.0296
# Epoch 39/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 429ms/step - accuracy: 0.8149 - loss: 0.0558 - val_accuracy: 0.7983 - val_loss: 0.0300
# Epoch 40/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 430ms/step - accuracy: 0.8141 - loss: 0.0522 - val_accuracy: 0.7983 - val_loss: 0.0302
# Epoch 41/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 431ms/step - accuracy: 0.8149 - loss: 0.0538 - val_accuracy: 0.7983 - val_loss: 0.0304
# Epoch 42/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 433ms/step - accuracy: 0.8154 - loss: 0.0540 - val_accuracy: 0.7983 - val_loss: 0.0300
# Epoch 43/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 432ms/step - accuracy: 0.8154 - loss: 0.0555 - val_accuracy: 0.7983 - val_loss: 0.0291
# Epoch 44/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 429ms/step - accuracy: 0.8154 - loss: 0.0552 - val_accuracy: 0.7983 - val_loss: 0.0285
# Epoch 45/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 427ms/step - accuracy: 0.8145 - loss: 0.0520 - val_accuracy: 0.7983 - val_loss: 0.0286
# Epoch 46/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 422ms/step - accuracy: 0.8149 - loss: 0.0520 - val_accuracy: 0.7983 - val_loss: 0.0288
# Epoch 47/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 421ms/step - accuracy: 0.8154 - loss: 0.0572 - val_accuracy: 0.7983 - val_loss: 0.0289
# Epoch 48/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 419ms/step - accuracy: 0.8145 - loss: 0.0548 - val_accuracy: 0.7983 - val_loss: 0.0289
# Epoch 49/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 421ms/step - accuracy: 0.8142 - loss: 0.0531 - val_accuracy: 0.7983 - val_loss: 0.0291
# Epoch 50/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 423ms/step - accuracy: 0.8149 - loss: 0.0552 - val_accuracy: 0.7983 - val_loss: 0.0294
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models
import cv2
import math
from google.colab import drive

drive.mount('/content/drive')

# Define paths for Ref and Non-Ref images
base_dir = '/content/drive/My Drive/dataset_Ref_Non_Ref'
reflection_dir = os.path.join(base_dir, 'Ref')  # Ref images
clear_dir = os.path.join(base_dir, 'Non_Ref')  # Non-Ref images

def load_images_from_folder(folder, target_size=(256, 256)):
    images = []
    for filename in sorted(os.listdir(folder)):
        img_path = os.path.join(folder, filename)
        img = cv2.imread(img_path)
        if img is not None:
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            img = cv2.resize(img, target_size)
            img = img / 255.0
            images.append(img)
    return np.array(images)


X_train = load_images_from_folder(reflection_dir)  # Ref images
Y_train = load_images_from_folder(clear_dir)  # Non-Ref images

print(f"Loaded {len(X_train)} images with reflections.")
print(f"Loaded {len(Y_train)} clear images.")

assert len(X_train) == len(Y_train), "Mismatch between input and output datasets."

# Define UNet model
def unet_model(input_shape=(256, 256, 3)):
    inputs = layers.Input(input_shape)

    # Encoder
    c1 = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(inputs)
    c1 = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(c1)
    p1 = layers.MaxPooling2D((2, 2))(c1)

    c2 = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(p1)
    c2 = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(c2)
    p2 = layers.MaxPooling2D((2, 2))(c2)

    c3 = layers.Conv2D(256, (3, 3), activation='relu', padding='same')(p2)
    c3 = layers.Conv2D(256, (3, 3), activation='relu', padding='same')(c3)
    p3 = layers.MaxPooling2D((2, 2))(c3)

    # Bottleneck
    c4 = layers.Conv2D(512, (3, 3), activation='relu', padding='same')(p3)
    c4 = layers.Conv2D(512, (3, 3), activation='relu', padding='same')(c4)

    # Decoder
    u5 = layers.Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(c4)
    u5 = layers.concatenate([u5, c3])
    c5 = layers.Conv2D(256, (3, 3), activation='relu', padding='same')(u5)
    c5 = layers.Conv2D(256, (3, 3), activation='relu', padding='same')(c5)

    u6 = layers.Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(c5)
    u6 = layers.concatenate([u6, c2])
    c6 = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(u6)
    c6 = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(c6)

    u7 = layers.Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(c6)
    u7 = layers.concatenate([u7, c1])
    c7 = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(u7)
    c7 = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(c7)

    outputs = layers.Conv2D(3, (1, 1), activation='sigmoid')(c7)

    model = models.Model(inputs, outputs)
    return model

model = unet_model()
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['accuracy'])
model.summary()

split_idx = int(0.8 * len(X_train))
X_train, X_val = X_train[:split_idx], X_train[split_idx:]
Y_train, Y_val = Y_train[:split_idx], Y_train[split_idx:]

batch_size = 16
num_epochs = 50

steps_per_epoch = math.ceil(len(X_train) / batch_size)
validation_steps = math.ceil(len(X_val) / batch_size)

def data_generator(X, Y, batch_size):
    while True:
        indices = np.random.permutation(len(X))
        for i in range(0, len(X), batch_size):
            batch_indices = indices[i:i + batch_size]
            X_batch = [X[j] for j in batch_indices]
            Y_batch = [Y[j] for j in batch_indices]
            yield np.array(X_batch), np.array(Y_batch)

train_gen = data_generator(X_train, Y_train, batch_size)
val_gen = data_generator(X_val, Y_val, batch_size)

history = model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=num_epochs,
    steps_per_epoch=steps_per_epoch,
    validation_steps=validation_steps
)
model.save('reflection_removal_unet.h5')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Loaded 30 images with reflections.
# Loaded 30 clear images.
# Model: "functional_12"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_12            │ (None, 256, 256, 3)    │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_180 (Conv2D)       │ (None, 256, 256, 64)   │          1,792 │ input_layer_12[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_181 (Conv2D)       │ (None, 256, 256, 64)   │         36,928 │ conv2d_180[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_36          │ (None, 128, 128, 64)   │              0 │ conv2d_181[0][0]       │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_182 (Conv2D)       │ (None, 128, 128, 128)  │         73,856 │ max_pooling2d_36[0][0] │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_183 (Conv2D)       │ (None, 128, 128, 128)  │        147,584 │ conv2d_182[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_37          │ (None, 64, 64, 128)    │              0 │ conv2d_183[0][0]       │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_184 (Conv2D)       │ (None, 64, 64, 256)    │        295,168 │ max_pooling2d_37[0][0] │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_185 (Conv2D)       │ (None, 64, 64, 256)    │        590,080 │ conv2d_184[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_38          │ (None, 32, 32, 256)    │              0 │ conv2d_185[0][0]       │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_186 (Conv2D)       │ (None, 32, 32, 512)    │      1,180,160 │ max_pooling2d_38[0][0] │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_187 (Conv2D)       │ (None, 32, 32, 512)    │      2,359,808 │ conv2d_186[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_36       │ (None, 64, 64, 256)    │        524,544 │ conv2d_187[0][0]       │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_36            │ (None, 64, 64, 512)    │              0 │ conv2d_transpose_36[0… │
# │ (Concatenate)             │                        │                │ conv2d_185[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_188 (Conv2D)       │ (None, 64, 64, 256)    │      1,179,904 │ concatenate_36[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_189 (Conv2D)       │ (None, 64, 64, 256)    │        590,080 │ conv2d_188[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_37       │ (None, 128, 128, 128)  │        131,200 │ conv2d_189[0][0]       │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_37            │ (None, 128, 128, 256)  │              0 │ conv2d_transpose_37[0… │
# │ (Concatenate)             │                        │                │ conv2d_183[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_190 (Conv2D)       │ (None, 128, 128, 128)  │        295,040 │ concatenate_37[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_191 (Conv2D)       │ (None, 128, 128, 128)  │        147,584 │ conv2d_190[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_38       │ (None, 256, 256, 64)   │         32,832 │ conv2d_191[0][0]       │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_38            │ (None, 256, 256, 128)  │              0 │ conv2d_transpose_38[0… │
# │ (Concatenate)             │                        │                │ conv2d_181[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_192 (Conv2D)       │ (None, 256, 256, 64)   │         73,792 │ concatenate_38[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_193 (Conv2D)       │ (None, 256, 256, 64)   │         36,928 │ conv2d_192[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_194 (Conv2D)       │ (None, 256, 256, 3)    │            195 │ conv2d_193[0][0]       │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 7,697,475 (29.36 MB)
#  Trainable params: 7,697,475 (29.36 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 16s 4s/step - accuracy: 0.3242 - loss: 0.0585 - val_accuracy: 0.7968 - val_loss: 0.0313
# Epoch 2/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 429ms/step - accuracy: 0.8127 - loss: 0.0539 - val_accuracy: 0.7983 - val_loss: 0.0306
# Epoch 3/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 424ms/step - accuracy: 0.8146 - loss: 0.0526 - val_accuracy: 0.7983 - val_loss: 0.0305
# Epoch 4/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 419ms/step - accuracy: 0.8149 - loss: 0.0536 - val_accuracy: 0.7983 - val_loss: 0.0307
# Epoch 5/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 423ms/step - accuracy: 0.8145 - loss: 0.0561 - val_accuracy: 0.7983 - val_loss: 0.0308
# Epoch 6/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 431ms/step - accuracy: 0.8146 - loss: 0.0563 - val_accuracy: 0.7983 - val_loss: 0.0306
# Epoch 7/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 424ms/step - accuracy: 0.8141 - loss: 0.0545 - val_accuracy: 0.7983 - val_loss: 0.0302
# Epoch 8/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 431ms/step - accuracy: 0.8145 - loss: 0.0544 - val_accuracy: 0.7983 - val_loss: 0.0301
# Epoch 9/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 432ms/step - accuracy: 0.8142 - loss: 0.0554 - val_accuracy: 0.7983 - val_loss: 0.0306
# Epoch 10/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 425ms/step - accuracy: 0.8149 - loss: 0.0544 - val_accuracy: 0.7983 - val_loss: 0.0316
# Epoch 11/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 424ms/step - accuracy: 0.8145 - loss: 0.0548 - val_accuracy: 0.7983 - val_loss: 0.0320
# Epoch 12/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 428ms/step - accuracy: 0.8145 - loss: 0.0529 - val_accuracy: 0.7983 - val_loss: 0.0318
# Epoch 13/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 431ms/step - accuracy: 0.8145 - loss: 0.0495 - val_accuracy: 0.7983 - val_loss: 0.0312
# Epoch 14/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 423ms/step - accuracy: 0.8149 - loss: 0.0527 - val_accuracy: 0.7983 - val_loss: 0.0307
# Epoch 15/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 430ms/step - accuracy: 0.8149 - loss: 0.0530 - val_accuracy: 0.7983 - val_loss: 0.0303
# Epoch 16/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 425ms/step - accuracy: 0.8154 - loss: 0.0562 - val_accuracy: 0.7983 - val_loss: 0.0300
# Epoch 17/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 427ms/step - accuracy: 0.8154 - loss: 0.0550 - val_accuracy: 0.7983 - val_loss: 0.0297
# Epoch 18/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 428ms/step - accuracy: 0.8154 - loss: 0.0560 - val_accuracy: 0.7983 - val_loss: 0.0296
# Epoch 19/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 434ms/step - accuracy: 0.8145 - loss: 0.0528 - val_accuracy: 0.7983 - val_loss: 0.0300
# Epoch 20/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 436ms/step - accuracy: 0.8163 - loss: 0.0562 - val_accuracy: 0.7983 - val_loss: 0.0306
# Epoch 21/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 444ms/step - accuracy: 0.8142 - loss: 0.0509 - val_accuracy: 0.7983 - val_loss: 0.0308
# Epoch 22/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 442ms/step - accuracy: 0.8159 - loss: 0.0558 - val_accuracy: 0.7983 - val_loss: 0.0307
# Epoch 23/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 440ms/step - accuracy: 0.8145 - loss: 0.0512 - val_accuracy: 0.7983 - val_loss: 0.0303
# Epoch 24/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 436ms/step - accuracy: 0.8150 - loss: 0.0541 - val_accuracy: 0.7983 - val_loss: 0.0299
# Epoch 25/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 430ms/step - accuracy: 0.8142 - loss: 0.0538 - val_accuracy: 0.7983 - val_loss: 0.0295
# Epoch 26/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 443ms/step - accuracy: 0.8142 - loss: 0.0537 - val_accuracy: 0.7983 - val_loss: 0.0293
# Epoch 27/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 435ms/step - accuracy: 0.8146 - loss: 0.0526 - val_accuracy: 0.7983 - val_loss: 0.0295
# Epoch 28/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 434ms/step - accuracy: 0.8158 - loss: 0.0575 - val_accuracy: 0.7983 - val_loss: 0.0300
# Epoch 29/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 440ms/step - accuracy: 0.8145 - loss: 0.0552 - val_accuracy: 0.7983 - val_loss: 0.0300
# Epoch 30/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 437ms/step - accuracy: 0.8145 - loss: 0.0524 - val_accuracy: 0.7983 - val_loss: 0.0301
# Epoch 31/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 450ms/step - accuracy: 0.8154 - loss: 0.0540 - val_accuracy: 0.7983 - val_loss: 0.0302
# Epoch 32/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 442ms/step - accuracy: 0.8145 - loss: 0.0538 - val_accuracy: 0.7983 - val_loss: 0.0301
# Epoch 33/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 444ms/step - accuracy: 0.8141 - loss: 0.0537 - val_accuracy: 0.7983 - val_loss: 0.0301
# Epoch 34/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 448ms/step - accuracy: 0.8145 - loss: 0.0537 - val_accuracy: 0.7983 - val_loss: 0.0301
# Epoch 35/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 451ms/step - accuracy: 0.8145 - loss: 0.0536 - val_accuracy: 0.7983 - val_loss: 0.0298
# Epoch 36/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 452ms/step - accuracy: 0.8145 - loss: 0.0555 - val_accuracy: 0.7983 - val_loss: 0.0298
# Epoch 37/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 444ms/step - accuracy: 0.8154 - loss: 0.0554 - val_accuracy: 0.7983 - val_loss: 0.0301
# Epoch 38/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 447ms/step - accuracy: 0.8158 - loss: 0.0556 - val_accuracy: 0.7983 - val_loss: 0.0300
# Epoch 39/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 440ms/step - accuracy: 0.8149 - loss: 0.0537 - val_accuracy: 0.7983 - val_loss: 0.0293
# Epoch 40/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 440ms/step - accuracy: 0.8154 - loss: 0.0553 - val_accuracy: 0.7983 - val_loss: 0.0287
# Epoch 41/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 442ms/step - accuracy: 0.8150 - loss: 0.0566 - val_accuracy: 0.7983 - val_loss: 0.0285
# Epoch 42/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 434ms/step - accuracy: 0.8154 - loss: 0.0550 - val_accuracy: 0.7983 - val_loss: 0.0297
# Epoch 43/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 434ms/step - accuracy: 0.8145 - loss: 0.0522 - val_accuracy: 0.7983 - val_loss: 0.0293
# Epoch 44/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 432ms/step - accuracy: 0.8149 - loss: 0.0576 - val_accuracy: 0.7983 - val_loss: 0.0299
# Epoch 45/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 437ms/step - accuracy: 0.8150 - loss: 0.0551 - val_accuracy: 0.7983 - val_loss: 0.0295
# Epoch 46/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 447ms/step - accuracy: 0.8146 - loss: 0.0534 - val_accuracy: 0.7983 - val_loss: 0.0286
# Epoch 47/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 438ms/step - accuracy: 0.8149 - loss: 0.0537 - val_accuracy: 0.7983 - val_loss: 0.0289
# Epoch 48/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 446ms/step - accuracy: 0.8149 - loss: 0.0521 - val_accuracy: 0.7983 - val_loss: 0.0293
# Epoch 49/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 440ms/step - accuracy: 0.8142 - loss: 0.0534 - val_accuracy: 0.7983 - val_loss: 0.0290
# Epoch 50/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 428ms/step - accuracy: 0.8154 - loss: 0.0553 - val_accuracy: 0.7983 - val_loss: 0.0292
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
from google.colab import drive
import shutil
import os

drive.mount('/content/drive', force_remount=True)

colab_model_path = '/content/improved_unet_reflection_removal.h5'

drive_model_folder = '/content/drive/MyDrive/your_model_folder1/'

os.makedirs(drive_model_folder, exist_ok=True)

drive_model_path = os.path.join(drive_model_folder, 'improved_unet_reflection_removal.h5')

if not os.path.exists(colab_model_path):
    print(f"Error: The model file does not exist at {colab_model_path}")
else:
    shutil.copy(colab_model_path, drive_model_path)

    if os.path.exists(drive_model_path):
        print(f"Model successfully saved to Google Drive at: {drive_model_path}")
    else:
        print("Error: Model not found in the specified Google Drive path.")
# Out:
# Mounted at /content/drive
# Model successfully saved to Google Drive at: /content/drive/MyDrive/your_model_folder1/improved_unet_reflection_removal.h5
